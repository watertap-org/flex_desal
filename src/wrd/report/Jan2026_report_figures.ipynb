# %% [markdown]
# # Figures for the January 2026 Quarterly Report

# %% [markdown]
# ### List of Required Figures
# 1) UF and RO pump comparison (MUKTA)
#     - Predicted pump power vs. measured, with bar charts and acceptable error bars
# Jake:
# 2) UF Power and Permeate production
#     - Bar chart w/ error bars/
# 3) RO Power and Permeate production
#     - Bar chart w/ error bars/
#     - perameter sweep for A,B,feed salinity (?), and perm back pressure (?)
# 4) UV Power and Permeate production
#     - Bar chart w/ error bars
# 5) Total operational costs
#     - Bar charts for chem, electricity, and brine disposal
# 6) Total  power consumption accross a month
#     - Like Figure 4 onwards in prev. quarterly report

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Water TAP vs. Digital Twin vs. Facility Data

# %%
# UF Power Use
# [Pump 1, Pump 2, Pump 3, Pump 4] 
measured_power_8_19 = [178,178,80,0] # Check which pumps are actually on
modeled_power_8_19 = [36,36,20,0]
DT_power_8_19 = 400 # Missing!!!

# March
measured_power_3_13 = 108
modeled_power_3_13 = 34.7
DT_power_3_13 = 100 # MISSING




fig_1, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Subplot 1: 8/19 Power data
categories_1 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_1 = [measured_power_8_19, modeled_power_8_19, DT_power_8_19]
ax1.fill_between(np.array([-1,3]), DT_power_8_19 * 0.85, DT_power_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax1.bar(categories_1, values_1, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax1.text(1.15, DT_power_8_19 + 5, '±15% DT Range', color='black', fontsize=12, ha='center')
ax1.set_ylabel('Power (kW)', fontsize=16)
ax1.set_title('UF Pump Power - 8/19', fontsize=16)
ax1.set_ylim([0, 130])
ax1.set_xlim(([-1,3]))
ax1.tick_params(labelsize=16)
plt.setp(ax1.get_xticklabels(), rotation=30, ha='right')

# Subplot 2: 3/13 Power data
categories_2 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_2 = [measured_power_3_13, modeled_power_3_13, DT_power_3_13]
ax2.fill_between(np.array([-1,3]), DT_power_3_13 * 0.85, DT_power_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax2.bar(categories_2, values_2, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax2.text(1.15, DT_power_3_13 + 0.15, '±15% DT Range', color='black', fontsize=12, ha='center')
ax2.set_ylabel('Power (kW)', fontsize=16)
ax2.set_title('UF Pump Power - 3/13', fontsize=16)
ax2.set_ylim([0, 130])
ax2.set_xlim(([-1,3]))
ax2.tick_params(labelsize=16)
plt.setp(ax2.get_xticklabels(), rotation=30, ha='right')
plt.tight_layout()
plt.savefig('UF_Pump_Power_Comparison.png', dpi=300)

# %%
# PRO 1 Power Use and Permeate Production
# Data Points: 8/19/2024 and 3/13/2024
measured_power_8_19 = 196.25
modeled_power_8_19 =  170.1
DT_power_8_19 = 203.0

measured_perm_8_19 = 1608.2
modeled_perm_8_19 =  1436.8
DT_perm_8_19 = 1602.4

measured_power_3_13 = 189.6
modeled_power_3_13 =  180.6
DT_power_3_13 = 203.9

measured_perm_3_13 = 1404.7
modeled_perm_3_13 =  1581.1
DT_perm_3_13 = 1468

fig_2, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))

# Subplot 1: 8/19 Power data
categories_1 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_1 = [measured_power_8_19, modeled_power_8_19, DT_power_8_19]
ax1.fill_between(np.array([-1,3]), DT_power_8_19 * 0.85, DT_power_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax1.bar(categories_1, values_1, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax1.text(1, DT_power_8_19 + 8, '±15% DT Range', color='black', fontsize=12, ha='center')
# eb1 = ax1.errorbar(2,DT_power_8_19,yerr=DT_power_8_19 * 0.15,  color='black', capsize=40, linewidth=2)
# eb1[-1][0].set_linestyle('--')
ax1.set_ylabel('Power (kW)', fontsize=14)
ax1.set_title('PRO 1 Power - 8/19', fontsize=14)
ax1.set_ylim([0, 250])
ax1.set_xlim(([-1,3]))
ax1.tick_params(labelsize=14)
plt.setp(ax1.get_xticklabels(), rotation=30, ha='right')

# Subplot 2: 3/13 Power data
categories_2 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_2 = [measured_power_3_13, modeled_power_3_13, DT_power_3_13]
ax2.fill_between(np.array([-1,3]), DT_power_3_13 * 0.85, DT_power_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax2.bar(categories_2, values_2, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax2.set_ylabel('Power (kW)', fontsize=14)
ax2.set_title('PRO 1 Power - 3/13', fontsize=14)
ax2.set_ylim([0, 250])
ax2.set_xlim(([-1,3]))
ax2.tick_params(labelsize=14)
plt.setp(ax2.get_xticklabels(), rotation=30, ha='right')

# Subplot 3: 8/19 Permeate data
categories_3 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_3 = [measured_perm_8_19, modeled_perm_8_19, DT_perm_8_19]
ax3.fill_between(np.array([-1,3]), DT_perm_8_19 * 0.85, DT_perm_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax3.bar(categories_3, values_3, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax3.set_ylabel('Permeate Flow (gpm)', fontsize=14)
ax3.set_title('PRO 1 Permeate - 8/19', fontsize=14)
ax3.set_ylim([0, max(values_3) * 1.25])
ax3.tick_params(labelsize=14)
plt.setp(ax3.get_xticklabels(), rotation=30, ha='right')

# Subplot 4: 3/13 Permeate data
categories_4 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_4 = [measured_perm_3_13, modeled_perm_3_13, DT_perm_3_13]
ax4.fill_between(np.array([-1,3]), DT_perm_3_13 * 0.85, DT_perm_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax4.bar(categories_4, values_4, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)

ax4.set_ylabel('Permeate Flow (gpm)', fontsize=14)
ax4.set_title('PRO 1 Permeate - 3/13', fontsize=14)
ax4.set_ylim([0, max(values_4) * 1.25])
ax4.tick_params(labelsize=14)
plt.setp(ax4.get_xticklabels(), rotation=30, ha='right')

plt.tight_layout()
plt.savefig('PRO1_Power_Comparison.png', dpi=300)

# %%
# PRO 2 Power Use and Permeate Production
# Data Points: 8/19/2024 and 3/13/2024
measured_power_8_19 = 22.71
modeled_power_8_19 =  21.4
DT_power_8_19 = 20.77

measured_perm_8_19 = 635
modeled_perm_8_19 =  649.6
DT_perm_8_19 = 652.8

measured_power_3_13 = 22.8
modeled_power_3_13 = 15.7
DT_power_3_13 = 20.66

measured_perm_3_13 = 617.05
modeled_perm_3_13 =  629.6
DT_perm_3_13 = 635.1

fig_3, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))

# Subplot 1: 8/19 Power data
categories_1 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_1 = [measured_power_8_19, modeled_power_8_19, DT_power_8_19]
ax1.fill_between(np.array([-1,3]), DT_power_8_19 * 0.85, DT_power_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax1.bar(categories_1, values_1, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax1.text(1.15, DT_power_8_19 + 1.25, '±15% DT Range', color='black', fontsize=12, ha='center')
ax1.set_ylabel('Power (kW)', fontsize=14)
ax1.set_title('PRO 2 Power - 8/19', fontsize=14)
ax1.set_ylim([0, 30])
ax1.set_xlim(([-1,3]))
ax1.tick_params(labelsize=14)
plt.setp(ax1.get_xticklabels(), rotation=30, ha='right')

# Subplot 2: 3/13 Power data
categories_2 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_2 = [measured_power_3_13, modeled_power_3_13, DT_power_3_13]
ax2.fill_between(np.array([-1,3]), DT_power_3_13 * 0.85, DT_power_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax2.bar(categories_2, values_2, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax2.text(1, DT_power_3_13 + 2, '±15% DT Range', color='black', fontsize=12, ha='center')
ax2.set_ylabel('Power (kW)', fontsize=14)
ax2.set_title('PRO 2 Power - 3/13', fontsize=14)
ax2.set_ylim([0, 30])
ax2.set_xlim(([-1,3]))
ax2.tick_params(labelsize=14)
plt.setp(ax2.get_xticklabels(), rotation=30, ha='right')

# Subplot 3: 8/19 Perm Data
categories_3 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_3 = [measured_perm_8_19, modeled_perm_8_19, DT_perm_8_19]
ax3.fill_between(np.array([-1,3]), DT_perm_8_19 * 0.85, DT_perm_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax3.bar(categories_3, values_3, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax3.text(1, DT_perm_8_19 + 8, '±15% DT Range', color='black', fontsize=12, ha='center')
ax3.set_ylabel('Permeate (gpd)', fontsize=14)
ax3.set_title('PRO 2 Permeate - 8/19', fontsize=14)
ax3.set_ylim([0, 775])
ax3.set_xlim(([-1,3]))
ax3.tick_params(labelsize=14)
plt.setp(ax3.get_xticklabels(), rotation=30, ha='right')

# Subplot 4: 3/13 Perm Data
categories_4 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_4 = [measured_perm_3_13, modeled_perm_3_13, DT_perm_3_13]
ax4.fill_between(np.array([-1,3]), DT_perm_3_13 * 0.85, DT_perm_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax4.bar(categories_4, values_4, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax4.text(1, DT_perm_3_13 + 8, '±15% DT Range', color='black', fontsize=12, ha='center')
ax4.set_ylabel('Permeate (gpd)', fontsize=14)
ax4.set_title('PRO 2 Permeate - 3/13', fontsize=14)
ax4.set_ylim([0, 775])
ax4.set_xlim(([-1,3]))
ax4.tick_params(labelsize=14)
plt.setp(ax4.get_xticklabels(), rotation=30, ha='right')

plt.tight_layout()
plt.savefig('PRO2_Power_Comparison.png', dpi=300)

# %%
# TSRO Power Use and Permeate Production
# Data Points: 8/19/2024 and 3/13/2024
measured_power_8_19 = 29.3
modeled_power_8_19 =  22.1
DT_power_8_19 = 20.27

measured_perm_8_19 = 197.97
modeled_perm_8_19 =  262.9
DT_perm_8_19 = 217.5

measured_power_3_13 = 24.9
modeled_power_3_13 = 15.5
DT_power_3_13 = 21.0

measured_perm_3_13 = 278.5
modeled_perm_3_13 =  107
DT_perm_3_13 = 270.23

fig_4, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))

# Subplot 1: 8/19 Power data
categories_1 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_1 = [measured_power_8_19, modeled_power_8_19, DT_power_8_19]
ax1.fill_between(np.array([-1,3]), DT_power_8_19 * 0.85, DT_power_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax1.bar(categories_1, values_1, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax1.text(2.2, DT_power_8_19 + 1.6, '±15% DT Range', color='black', fontsize=12, ha='center')
ax1.set_ylabel('Power (kW)', fontsize=16)
ax1.set_title('TSRO Power - 8/19', fontsize=16)
ax1.set_ylim([0, 35])
ax1.set_xlim(([-1,3]))
ax1.tick_params(labelsize=16)
plt.setp(ax1.get_xticklabels(), rotation=30, ha='right')

# Subplot 2: 3/13 Power data
categories_2 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_2 = [measured_power_3_13, modeled_power_3_13, DT_power_3_13]
ax2.fill_between(np.array([-1,3]), DT_power_3_13 * 0.85, DT_power_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax2.bar(categories_2, values_2, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax2.text(1, DT_power_3_13 + 2, '±15% DT Range', color='black', fontsize=12, ha='center')
ax2.set_ylabel('Power (kW)', fontsize=16)
ax2.set_title('TSRO Power - 3/13', fontsize=16)
ax2.set_ylim([0, 35])
ax2.set_xlim(([-1,3]))
ax2.tick_params(labelsize=16)
plt.setp(ax2.get_xticklabels(), rotation=30, ha='right')

# Subplot 3: 8/19 Perm Data
categories_3 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_3 = [measured_perm_8_19, modeled_perm_8_19, DT_perm_8_19]
ax3.fill_between(np.array([-1,3]), DT_perm_8_19 * 0.85, DT_perm_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax3.bar(categories_3, values_3, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax3.text(1, DT_perm_8_19 + 8, '±15% DT Range', color='black', fontsize=12, ha='center')
ax3.set_ylabel('Permeate (gpd)', fontsize=16)
ax3.set_title('TSRO Permeate - 8/19', fontsize=16)
ax3.set_ylim([0, 400])
ax3.set_xlim(([-1,3]))
ax3.tick_params(labelsize=16)
plt.setp(ax3.get_xticklabels(), rotation=30, ha='right')

# Subplot 4: 3/13 Perm Data
categories_4 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_4 = [measured_perm_3_13, modeled_perm_3_13, DT_perm_3_13]
ax4.fill_between(np.array([-1,3]), DT_perm_3_13 * 0.85, DT_perm_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax4.bar(categories_4, values_4, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax4.text(1, DT_perm_3_13 + 8, '±15% DT Range', color='black', fontsize=12, ha='center')
ax4.set_ylabel('Permeate (gpd)', fontsize=16)
ax4.set_title('TSRO Permeate - 3/13', fontsize=16)
ax4.set_ylim([0, 400])
ax4.set_xlim(([-1,3]))
ax4.tick_params(labelsize=16)
plt.setp(ax4.get_xticklabels(), rotation=30, ha='right')

plt.tight_layout()
plt.savefig('TSRO_Power_Comparison.png', dpi=300)

# %%
# UV-AOP
measured_power_8_19 = 54.5
modeled_power_8_19 =  53.6
DT_power_8_19 = 55 # MISSING

measured_power_3_13 = 52
modeled_power_3_13 = 51.7
DT_power_3_13 = 54 # MISSING

fig_5, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Subplot 1: 8/19 Power data
categories_1 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_1 = [measured_power_8_19, modeled_power_8_19, DT_power_8_19]
ax1.fill_between(np.array([-1,3]), DT_power_8_19 * 0.85, DT_power_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax1.bar(categories_1, values_1, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax1.text(1.15, DT_power_8_19 + 5, '±15% DT Range', color='black', fontsize=12, ha='center')
ax1.set_ylabel('Power (kW)', fontsize=16)
ax1.set_title('UV-AOP Power - 8/19', fontsize=16)
ax1.set_ylim([0, 70])
ax1.set_xlim(([-1,3]))
ax1.tick_params(labelsize=16)
plt.setp(ax1.get_xticklabels(), rotation=30, ha='right')

# Subplot 2: 3/13 Power data
categories_2 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_2 = [measured_power_3_13, modeled_power_3_13, DT_power_3_13]
ax2.fill_between(np.array([-1,3]), DT_power_3_13 * 0.85, DT_power_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax2.bar(categories_2, values_2, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax2.text(1.15, DT_power_3_13 + 0.15, '±15% DT Range', color='black', fontsize=12, ha='center')
ax2.set_ylabel('Power (kW)', fontsize=16)
ax2.set_title('UV-AOP Power - 3/13', fontsize=16)
ax2.set_ylim([0, 70])
ax2.set_xlim(([-1,3]))
ax2.tick_params(labelsize=16)
plt.setp(ax2.get_xticklabels(), rotation=30, ha='right')
plt.tight_layout()
plt.savefig('UV_AOP_Power_Comparison.png', dpi=300)

# %%
# Decarbonator
measured_power_8_19 = 2.2
modeled_power_8_19 =  2.5
DT_power_8_19 = 2.4 # MISSING

measured_power_3_13 = 2.4
modeled_power_3_13 = 2.5
DT_power_3_13 = 2.4

fig_6, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Subplot 1: 8/19 Power data
categories_1 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_1 = [measured_power_8_19, modeled_power_8_19, DT_power_8_19]
ax1.fill_between(np.array([-1,3]), DT_power_8_19 * 0.85, DT_power_8_19 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax1.bar(categories_1, values_1, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax1.text(1.15, DT_power_8_19 + 0.15, '±15% DT Range', color='black', fontsize=12, ha='center')
ax1.set_ylabel('Power (kW)', fontsize=16)
ax1.set_title('Decarbonator Power - 8/19', fontsize=16)
ax1.set_ylim([0, 3])
ax1.set_xlim(([-1,3]))
ax1.tick_params(labelsize=16)
plt.setp(ax1.get_xticklabels(), rotation=30, ha='right')

# Subplot 2: 3/13 Power data
categories_2 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_2 = [measured_power_3_13, modeled_power_3_13, DT_power_3_13]
ax2.fill_between(np.array([-1,3]), DT_power_3_13 * 0.85, DT_power_3_13 * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax2.bar(categories_2, values_2, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax2.text(1.15, DT_power_3_13 + 0.15, '±15% DT Range', color='black', fontsize=12, ha='center')
ax2.set_ylabel('Power (kW)', fontsize=16)
ax2.set_title('Decarbonator Power - 3/13', fontsize=16)
ax2.set_ylim([0, 3])
ax2.set_xlim(([-1,3]))
ax2.tick_params(labelsize=16)
plt.setp(ax2.get_xticklabels(), rotation=30, ha='right')
plt.tight_layout()
plt.savefig('Decarbonator_Power_Comparison.png', dpi=300)

# %% [markdown]
# ### WaterTAP vs. Facility Costs

# %%
# Feed Water Costs, per unit of water produced
reported_cost_aug = 241400/1348194
modeled_cost_aug = .15

reported_cost_mar = 205820/1255436
modeled_cost_mar = .15

fig_3, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Subplot 1: 8/19 data
categories_1 = ['Reported', 'Modeled']
values_1 = [reported_cost_aug, modeled_cost_aug]
ax1.bar(categories_1, values_1, color=['coral', 'steelblue'])
eb1 = ax1.errorbar(0,reported_cost_aug,yerr=reported_cost_aug * 0.15,  color='black', capsize=15, linewidth=2)
eb1[-1][0].set_linestyle('--')
ax1.set_ylabel('Cost ($/m^3)', fontsize=14)
ax1.set_title('Feed Water Costs - 8/19/21', fontsize=14)
ax1.set_ylim([0, max(values_1) * 1.25])
ax1.tick_params(labelsize=14)

# Subplot 2: 3/13 data
categories_2 = ['Reported', 'Modeled']
values_2 = [reported_cost_mar, modeled_cost_mar]
ax2.bar(categories_2, values_2, color=['coral', 'steelblue'])
eb2 = ax2.errorbar(0,reported_cost_mar,yerr=reported_cost_mar * 0.15,  color='black', capsize=15, linewidth=2)
eb2[-1][0].set_linestyle('--')
ax2.set_ylabel('Cost ($/m^3)', fontsize=14)
ax2.set_title('Feed Water Costs - 3/13/21', fontsize=14)
ax2.set_ylim([0, max(values_2) * 1.25])
ax2.tick_params(labelsize=14)

plt.tight_layout()
plt.savefig('Feed_Water_Costs_Comparison.png', dpi=300)

# %%
# Total Operational Costs, per unit of water produced
reported_cost_aug = 0.464
modeled_cost_aug = .5

reported_cost_mar = 0.490
modeled_cost_mar = .5

fig_3, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Subplot 1: 8/19 data
categories_1 = ['Reported', 'Modeled']
values_1 = [reported_cost_aug, modeled_cost_aug]
ax1.bar(categories_1, values_1, color=['coral', 'steelblue'])
eb1 = ax1.errorbar(0,reported_cost_aug,yerr=reported_cost_aug * 0.15,  color='black', capsize=15, linewidth=2)
eb1[-1][0].set_linestyle('--')
ax1.set_ylabel('Cost ($/m^3)', fontsize=14)
ax1.set_title('Total Operational Costs - 8/19/21', fontsize=14)
ax1.set_ylim([0, max(values_1) * 1.25])
ax1.tick_params(labelsize=14)

# Subplot 2: 3/13 data
categories_2 = ['Reported', 'Modeled']
values_2 = [reported_cost_mar, modeled_cost_mar]
ax2.bar(categories_2, values_2, color=['coral', 'steelblue'])
eb2 = ax2.errorbar(0,reported_cost_mar,yerr=reported_cost_mar * 0.15,  color='black', capsize=15, linewidth=2)
eb2[-1][0].set_linestyle('--')
ax2.set_ylabel('Cost ($/m^3)', fontsize=14)
ax2.set_title('Total Operational Costs - 3/13/21', fontsize=14)
ax2.set_ylim([0, max(values_2) * 1.25])
ax2.tick_params(labelsize=14)

plt.tight_layout()
plt.savefig('Total_Operational_Costs_Comparison.png', dpi=300)

# %% [markdown]
# ### Facility Data

# %%
# UV-AOP Linear Fit Against Data
# Can't Really include here because it requires loading the data files we don't want on the public repo.
# See Flex_desal_old Data_Exploration

# %% [markdown]
# ### Alternate Version of the UF Comparison

# %%
# Data Point from: 3/13/2021, but essentially the same as 8/19/2021
# Estimated flowrate of 3955 gpm
measured_power_full = 178
modeled_power_full =  48.65
DT_power_full = modeled_power_full

#Estimated flowrate of 1785 gpm
measured_power_half = 79
modeled_power_half =  30.8
DT_power_half = modeled_power_half

fig_1, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Subplot 1: 8/19 Power data
categories_1 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_1 = [measured_power_full, modeled_power_full, DT_power_full]
ax1.fill_between(np.array([-1,3]), DT_power_full * 0.85, DT_power_full * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax1.bar(categories_1, values_1, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
ax1.text(1.15, DT_power_full + 5, '±15% DT Range', color='black', fontsize=12, ha='center')
ax1.set_ylabel('Power (kW)', fontsize=16)
ax1.set_title('UF Pump Power, Full Flow', fontsize=16)
ax1.set_ylim([0, 200])
ax1.set_xlim(([-1,3]))
ax1.tick_params(labelsize=16)
plt.setp(ax1.get_xticklabels(), rotation=30, ha='right')

# Subplot 2: 3/13 Power data
categories_2 = ['WRD Data', 'WaterTAP', 'Digital Twin']
values_2 = [measured_power_half, modeled_power_half, DT_power_half]
ax2.fill_between(np.array([-1,3]), DT_power_half * 0.85, DT_power_half * 1.15, color='lightgreen', alpha=.6, label='±15% DT Range',edgecolor='black',linewidth=1)
ax2.bar(categories_2, values_2, color=['coral', 'steelblue', 'green'],edgecolor='black',linewidth=.5)
# ax2.text(1.15, DT_power_half + 0.15, '±15% DT Range', color='black', fontsize=12, ha='center')
ax2.set_ylabel('Power (kW)', fontsize=16)
ax2.set_title('UF Pump Power, Low Flow', fontsize=16)
ax2.set_ylim([0, 100])
ax2.set_xlim(([-1,3]))
ax2.tick_params(labelsize=16)
plt.setp(ax2.get_xticklabels(), rotation=30, ha='right')
plt.tight_layout()
plt.savefig('UF_Individual_Pump_Comparison.png', dpi=300)

# %% [markdown]
# ### Membrane Properties Plot

# %%
month = 8
perm_data = pd.read_csv("C:\\Users\\rchurchi\\flex_desal\\src\\wrd\\membrane_properties\\memb_perm_values_PRO1_1_aug.csv")
perm_data = perm_data[:-5]
# TODO: Have all dates in the month on x-axis but only plot the values we have.

# %%
fig_12 = plt.figure(figsize=(8,6))
print(perm_data['DateTime'])
print(perm_data['A'])
plt.plot(perm_data['DateTime'], perm_data['A'], color='coral', marker='o',linestyle='None')
plt.xlabel('Date', fontsize=14)
plt.xticks(rotation=30, ha='right', fontsize=8)
plt.ylabel('Water Permeability (m/s/Pa)', fontsize=14)
plt.ylim([0, 1e-11])
plt.title('PRO 1-1 Water Membrane Permeability August', fontsize=16)
# Out:
# 0      8/1/2021
# 1      8/2/2021
# 2      8/3/2021
# 3      8/4/2021
# 4      8/5/2021
# 5      8/6/2021
# 6      8/7/2021
# 7     8/10/2021
# 8     8/11/2021
# 9     8/13/2021
# 10    8/14/2021
# 11    8/15/2021
# 12    8/16/2021
# 13    8/17/2021
# 14    8/18/2021
# 15    8/19/2021
# 16    8/20/2021
# 17    8/21/2021
# 18    8/22/2021
# 19    8/23/2021
# 20    8/24/2021
# 21    8/25/2021
# 22    8/26/2021
# Name: DateTime, dtype: object
# 0     7.050000e-12
# 1     7.170000e-12
# 2     7.100000e-12
# 3     7.310000e-12
# 4     7.230000e-12
# 5     7.160000e-12
# 6     7.150000e-12
# 7     7.350000e-12
# 8     7.380000e-12
# 9     7.590000e-12
# 10    7.140000e-12
# 11    7.460000e-12
# 12    7.510000e-12
# 13    7.350000e-12
# 14    7.640000e-12
# 15    7.270000e-12
# 16    7.330000e-12
# 17    7.170000e-12
# 18    7.220000e-12
# 19    7.300000e-12
# 20    7.360000e-12
# 21    7.410000e-12
# 22    7.640000e-12
# Name: A, dtype: float64
# Text(0.5, 1.0, 'PRO 1-1 Water Membrane Permeability August')
